# %% [markdown]
# # Import General Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('Downloads/data_lokasi_busway_jakarta_latlong.csv', index_col=None, header=0)
df
# Out:
#         koridor  koridor_no       rute_koridor        nama_halte  \
# 0     Koridor 1           1      Blok M - Kota   TERMINAL BLOK M
# 1     Koridor 1           1      Blok M - Kota   MESJID AL-AZHAR
# 2     Koridor 1           1      Blok M - Kota  BUNDARAN SENAYAN
# 3     Koridor 1           1      Blok M - Kota            GELORA
# 4     Koridor 1           1      Blok M - Kota             POLDA
# ..          ...         ...                ...               ...
# 219  Koridor 13          13  Ciledug - Tendean            VELBAK
# 220  Koridor 13          13  Ciledug - Tendean          MAYESTIK
# 221  Koridor 13          13  Ciledug - Tendean         TIRTAYASA
# 222  Koridor 13          13  Ciledug - Tendean        RAWA BARAT
# 223  Koridor 13          13  Ciledug - Tendean           TENDEAN
#
#              lokasi_halte dibangun_tahun  \
# 0         TERMINAL BLOK M           2003
# 1    JL. SISINGAMANGARAJA           2003
# 2       JL. JEND SUDIRMAN           2003
# ...

# %%
df2 = pd.read_csv('Downloads/data_jumlah_penumpang_2020.csv', index_col=None, header=0)
df2
# Out:
#     jenis  koridor_no                                    trayek  \
# 0     BRT           1                 KORIDOR 1 (BLOK M - KOTA)
# 1     BRT           2        KORIDOR 2 (PULOGADUNG 1 - HARMONI)
# 2     BRT           3        KORIDOR 3 (KALIDERES - PASAR BARU)
# 3     BRT           4   KORIDOR 4 (PULOGADUNG 2 - DUKUH ATAS 2)
# 4     BRT           5        KORIDOR 5 (KAMPUNG MELAYU - ANCOL)
# ..    ...         ...                                       ...
# 138   BRT           9          KORIDOR 9 (PINANG RANTI - PLUIT)
# 139   BRT          10                KORIDOR 10 (PGC 2 - PLUIT)
# 140   BRT          11  KORIDOR 11 (PULOGEBANG - KAMPUNG MELAYU)
# 141   BRT          12  KORIDOR 12 (PENJARINGAN - TANJUNG PRIOK)
# 142   BRT          13         KORIDOR 13 (CBD CILEDUG - BLOK M)
#
#      jumlah_penumpang       month             month_ts
# 0             2686458  2020-01-01  2020-01-01T00:00:00
# 1              936927  2020-01-01  2020-01-01T00:00:00
# ...

# %%
df_merge = pd.merge(df, df2, on="koridor_no")
df_merge
# Out:
#          koridor  koridor_no       rute_koridor       nama_halte  \
# 0      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 1      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 2      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 3      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 4      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# ...          ...         ...                ...              ...
# 2459  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2460  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2461  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2462  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2463  Koridor 13          13  Ciledug - Tendean          TENDEAN
#
#          lokasi_halte dibangun_tahun keterangan       lat        long jenis  \
# 0     TERMINAL BLOK M           2003    PELICAN -6.243300  106.793291   BRT
# ...

# %% [markdown]
# # Initialize KeplerGl

# %%
from keplergl import KeplerGl 
map_1 = KeplerGl(height=800, width=800)
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(height=800)

# %%
df_test = pd.DataFrame()
df_test = df_merge
# df_merge[df_merge['month']=='2020-01-01']
df_test
# Out:
#          koridor  koridor_no       rute_koridor       nama_halte  \
# 0      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 1      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 2      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 3      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# 4      Koridor 1           1      Blok M - Kota  TERMINAL BLOK M
# ...          ...         ...                ...              ...
# 2459  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2460  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2461  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2462  Koridor 13          13  Ciledug - Tendean          TENDEAN
# 2463  Koridor 13          13  Ciledug - Tendean          TENDEAN
#
#          lokasi_halte dibangun_tahun keterangan       lat        long jenis  \
# 0     TERMINAL BLOK M           2003    PELICAN -6.243300  106.793291   BRT
# ...

# %%
import geopandas as gpd

# Create a gepdataframe
gdf = gpd.GeoDataFrame(df_merge, geometry=gpd.points_from_xy(df_merge.long, df_merge.lat))
# Add data to Kepler
map_1.add_data(data=gdf, name="jumlah_penumpang")

# map_1.add_data(data=df2, name="data_1")

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [{'dataId': ['jumlah_penumpang'], 'id': '…

# %%
config = map_1.config
config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [{'dataId': ['jumlah_penumpang'],
#      'id': 'bagsukxc',
#      'name': ['month_ts'],
#      'type': 'timeRange',
#      'value': [1581903792000, 1584808736000],
#      'enlarged': True,
#      'plotType': 'histogram',
#      'animationWindow': 'free',
#      'yAxis': None}],
#    'layers': [{'id': 'y14mjf',
#      'type': 'geojson',
#      'config': {'dataId': 'jumlah_penumpang',
#       'label': 'point_map',
#       'color': [23, 184, 190],
#       'columns': {'geojson': 'geometry'},
#       'isVisible': False,
#       'visConfig': {'opacity': 0.8,
#        'strokeOpacity': 0.8,
#        'thickness': 0.5,
#        'strokeColor': None,
#        'colorRange': {'name': 'Uber Viz Qualitative 3',
#         'type': 'qualitative',
#         'category': 'Uber',
#         'colors': ['#12939A',
#          '#DDB27C',
#          '#88572C',
#          '#FF991F',
#          '#F15C17',
#          '#223F9A',
#          '#DA70BF',
# ...

# %%
# Save current map directly
map_1.save_to_html(file_name="my_keplergl_map.html")

# Save map using other data or config
map_1.save_to_html(data={'data_1': df_merge}, config=config, file_name="my_keplergl_map.html")
# Out:
# Map saved to my_keplergl_map.html!

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': 'y14mjf', 'type': '…

# %%
df_test[['koridor','rute_koridor','nama_halte','lokasi_halte','dibangun_tahun','lat','long','jumlah_penumpang','month_ts']]
# Out:
#          koridor       rute_koridor       nama_halte     lokasi_halte  \
# 0      Koridor 1      Blok M - Kota  TERMINAL BLOK M  TERMINAL BLOK M
# 1      Koridor 1      Blok M - Kota  TERMINAL BLOK M  TERMINAL BLOK M
# 2      Koridor 1      Blok M - Kota  TERMINAL BLOK M  TERMINAL BLOK M
# 3      Koridor 1      Blok M - Kota  TERMINAL BLOK M  TERMINAL BLOK M
# 4      Koridor 1      Blok M - Kota  TERMINAL BLOK M  TERMINAL BLOK M
# ...          ...                ...              ...              ...
# 2459  Koridor 13  Ciledug - Tendean          TENDEAN              NaN
# 2460  Koridor 13  Ciledug - Tendean          TENDEAN              NaN
# 2461  Koridor 13  Ciledug - Tendean          TENDEAN              NaN
# 2462  Koridor 13  Ciledug - Tendean          TENDEAN              NaN
# 2463  Koridor 13  Ciledug - Tendean          TENDEAN              NaN
#
#      dibangun_tahun       lat        long  jumlah_penumpang  \
# 0              2003 -6.243300  106.793291           2686458
# ...
